# %%
# %load_ext nb_black
import tensorflow as tf
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import pickle

# %%
# Import Dataset(s)
from emnist import list_datasets
list_datasets()
# Out:
# ['balanced', 'byclass', 'bymerge', 'digits', 'letters', 'mnist']

# %%
# Working with 'balanced'
# Import 
from emnist import extract_training_samples
images_train, labels_train = extract_training_samples('balanced')
from emnist import extract_test_samples
images_test, labels_test = extract_test_samples('balanced')

# %%
# Check shape of training and testing data
print(images_train.shape)
print(labels_train.shape)
print(images_test.shape)
print(labels_test.shape)
# Out:
# (112800, 28, 28)
# (112800,)
# (18800, 28, 28)
# (18800,)

# %%
X_train = np.expand_dims(images_train, 3)
y_train = labels_train

X_val = np.expand_dims(images_test, 3)
y_val = labels_test

# %%
print(X_train.shape)
print(y_train.shape)
print(X_val.shape)
print(y_val.shape)
# Out:
# (112800, 28, 28, 1)
# (112800,)
# (18800, 28, 28, 1)
# (18800,)

# %% [markdown]
# ## create mapping

# %%
import string
nums = list(string.digits)
upper = list(string.ascii_uppercase)
lower = list('abdefghnqrt')
classes = nums + upper + lower

mapping = {}
for i, value in enumerate(classes):
    mapping[i] = value
    pass

# %% [markdown]
# ## visualize dataset

# %%
plt.figure(figsize = (20, 8))
for i in range(10):
    plt.subplot(2, 5, i+1)
    plt.imshow(X_train[i].reshape(28, 28), cmap = 'gray')
    plt.title('{}'.format(mapping[y_train[i]]))
    plt.axis('off')
    pass
plt.show()

# %% [markdown]
# ## create dataset

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
test_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val))

# %%
BATCH_SIZE = 64
SHUFFLE_BUFFER_SIZE = 100

train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
test_dataset = test_dataset.batch(BATCH_SIZE)

# %%
train_dataset
# Out:
# <BatchDataset shapes: ((None, 28, 28, 1), (None,)), types: (tf.uint8, tf.uint8)>

# %% [markdown]
# ## train model

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(6, (5, 5), activation = 'relu', input_shape = (28, 28, 1), name = '1st_conv'),
    tf.keras.layers.AveragePooling2D(2, 2, name = '1st_pooling'),
    tf.keras.layers.Conv2D(16, (5, 5), activation = 'relu', name = '2nd_conv'),
    tf.keras.layers.AveragePooling2D(2, 2, name = '2nd_pooling'),
    tf.keras.layers.Flatten(name = 'flatten'),
    tf.keras.layers.Dropout(0.5, name = '1st_dropout'),
    tf.keras.layers.Dense(120,activation='relu', name = '1st_fc'),
    tf.keras.layers.Dense(84,activation='relu', name = '2nd_fc'),
    tf.keras.layers.Dense(47, name = '3rd_fc')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# 1st_conv (Conv2D)            (None, 24, 24, 6)         156
# _________________________________________________________________
# 1st_pooling (AveragePooling2 (None, 12, 12, 6)         0
# _________________________________________________________________
# 2nd_conv (Conv2D)            (None, 8, 8, 16)          2416
# _________________________________________________________________
# 2nd_pooling (AveragePooling2 (None, 4, 4, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# 1st_dropout (Dropout)        (None, 256)               0
# _________________________________________________________________
# 1st_fc (Dense)               (None, 120)               30840
# _________________________________________________________________
# 2nd_fc (Dense)               (None, 84)                10164
# _________________________________________________________________
# 3rd_fc (Dense)               (None, 47)                3995
# =================================================================
# Total params: 47,571
# Trainable params: 47,571
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(0.001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
)

callbacks = tf.keras.callbacks.EarlyStopping(
    monitor = 'val_sparse_categorical_accuracy', 
    patience = 10, 
    mode = 'auto'
)

# %%
history = model.fit(
    train_dataset,
    epochs=100,
    callbacks = [callbacks],
    validation_data=test_dataset,
)
# Out:
# Epoch 1/100
# 1763/1763 [==============================] - 31s 17ms/step - loss: 3.1104 - sparse_categorical_accuracy: 0.3105 - val_loss: 0.6964 - val_sparse_categorical_accuracy: 0.7713
# Epoch 2/100
# 1763/1763 [==============================] - 27s 15ms/step - loss: 0.9566 - sparse_categorical_accuracy: 0.6954 - val_loss: 0.5747 - val_sparse_categorical_accuracy: 0.8091
# Epoch 3/100
# 1763/1763 [==============================] - 28s 16ms/step - loss: 0.7889 - sparse_categorical_accuracy: 0.7457 - val_loss: 0.5295 - val_sparse_categorical_accuracy: 0.8156
# Epoch 4/100
# 1763/1763 [==============================] - 30s 17ms/step - loss: 0.7175 - sparse_categorical_accuracy: 0.7650 - val_loss: 0.5119 - val_sparse_categorical_accuracy: 0.8264
# Epoch 5/100
# 1763/1763 [==============================] - 29s 17ms/step - loss: 0.6766 - sparse_categorical_accuracy: 0.7746 - val_loss: 0.4988 - val_sparse_categorical_accuracy: 0.8294
# Epoch 6/100
# 1763/1763 [==============================] - 32s 18ms/step - loss: 0.6423 - sparse_categorical_accuracy: 0.7860 - val_loss: 0.4784 - val_sparse_categorical_accuracy: 0.8319
# Epoch 7/100
# 1763/1763 [==============================] - 29s 16ms/step - loss: 0.6244 - sparse_categorical_accuracy: 0.7891 - val_loss: 0.4484 - val_sparse_categorical_accuracy: 0.8446
# Epoch 8/100
# 1763/1763 [==============================] - 30s 17ms/step - loss: 0.6083 - sparse_categorical_accuracy: 0.7959 - val_loss: 0.4534 - val_sparse_categorical_accuracy: 0.8433
# Epoch 9/100
# 1763/1763 [==============================] - 33s 19ms/step - loss: 0.5986 - sparse_categorical_accuracy: 0.7983 - val_loss: 0.4439 - val_sparse_categorical_accuracy: 0.8474
# Epoch 10/100
# 1763/1763 [==============================] - 30s 17ms/step - loss: 0.5907 - sparse_categorical_accuracy: 0.8018 - val_loss: 0.4447 - val_sparse_categorical_accuracy: 0.8453
# Epoch 11/100
# 1763/1763 [==============================] - 33s 18ms/step - loss: 0.5815 - sparse_categorical_accuracy: 0.8033 - val_loss: 0.4395 - val_sparse_categorical_accuracy: 0.8476
# Epoch 12/100
# 1763/1763 [==============================] - 41s 23ms/step - loss: 0.5682 - sparse_categorical_accuracy: 0.8060 - val_loss: 0.4308 - val_sparse_categorical_accuracy: 0.8483
# Epoch 13/100
# 1763/1763 [==============================] - 38s 22ms/step - loss: 0.5650 - sparse_categorical_accuracy: 0.8092 - val_loss: 0.4243 - val_sparse_categorical_accuracy: 0.8493
# Epoch 14/100
# 1763/1763 [==============================] - 35s 20ms/step - loss: 0.5548 - sparse_categorical_accuracy: 0.8097 - val_loss: 0.4232 - val_sparse_categorical_accuracy: 0.8502
# Epoch 15/100
# 1763/1763 [==============================] - 33s 18ms/step - loss: 0.5532 - sparse_categorical_accuracy: 0.8122 - val_loss: 0.4264 - val_sparse_categorical_accuracy: 0.8510
# Epoch 16/100
# 1763/1763 [==============================] - 47s 26ms/step - loss: 0.5496 - sparse_categorical_accuracy: 0.8110 - val_loss: 0.4178 - val_sparse_categorical_accuracy: 0.8540
# Epoch 17/100
# 1763/1763 [==============================] - 40s 23ms/step - loss: 0.5485 - sparse_categorical_accuracy: 0.8129 - val_loss: 0.4205 - val_sparse_categorical_accuracy: 0.8563
# Epoch 18/100
# 1763/1763 [==============================] - 47s 26ms/step - loss: 0.5398 - sparse_categorical_accuracy: 0.8144 - val_loss: 0.4298 - val_sparse_categorical_accuracy: 0.8490
# Epoch 19/100
# 1763/1763 [==============================] - 31s 17ms/step - loss: 0.5389 - sparse_categorical_accuracy: 0.8145 - val_loss: 0.4193 - val_sparse_categorical_accuracy: 0.8560
# Epoch 20/100
# 1763/1763 [==============================] - 30s 17ms/step - loss: 0.5373 - sparse_categorical_accuracy: 0.8163 - val_loss: 0.4027 - val_sparse_categorical_accuracy: 0.8602
# Epoch 21/100
# 1763/1763 [==============================] - 31s 18ms/step - loss: 0.5349 - sparse_categorical_accuracy: 0.8179 - val_loss: 0.4112 - val_sparse_categorical_accuracy: 0.8570
# Epoch 22/100
# 1763/1763 [==============================] - 31s 18ms/step - loss: 0.5275 - sparse_categorical_accuracy: 0.8190 - val_loss: 0.4202 - val_sparse_categorical_accuracy: 0.8545
# Epoch 23/100
# 1763/1763 [==============================] - 31s 18ms/step - loss: 0.5284 - sparse_categorical_accuracy: 0.8167 - val_loss: 0.4074 - val_sparse_categorical_accuracy: 0.8578
# Epoch 24/100
# 1763/1763 [==============================] - 35s 20ms/step - loss: 0.5253 - sparse_categorical_accuracy: 0.8178 - val_loss: 0.4061 - val_sparse_categorical_accuracy: 0.8595
# Epoch 25/100
# 1763/1763 [==============================] - 35s 20ms/step - loss: 0.5234 - sparse_categorical_accuracy: 0.8206 - val_loss: 0.4155 - val_sparse_categorical_accuracy: 0.8543
# Epoch 26/100
# 1763/1763 [==============================] - 31s 18ms/step - loss: 0.5195 - sparse_categorical_accuracy: 0.8200 - val_loss: 0.3979 - val_sparse_categorical_accuracy: 0.8622
# Epoch 27/100
# 1763/1763 [==============================] - 33s 19ms/step - loss: 0.5192 - sparse_categorical_accuracy: 0.8203 - val_loss: 0.4133 - val_sparse_categorical_accuracy: 0.8562
# Epoch 28/100
# 1763/1763 [==============================] - 28s 16ms/step - loss: 0.5215 - sparse_categorical_accuracy: 0.8209 - val_loss: 0.4091 - val_sparse_categorical_accuracy: 0.8559
# Epoch 29/100
# 1763/1763 [==============================] - 27s 15ms/step - loss: 0.5183 - sparse_categorical_accuracy: 0.8212 - val_loss: 0.4091 - val_sparse_categorical_accuracy: 0.8599
# Epoch 30/100
# 1763/1763 [==============================] - 25s 14ms/step - loss: 0.5144 - sparse_categorical_accuracy: 0.8222 - val_loss: 0.4043 - val_sparse_categorical_accuracy: 0.8606
# Epoch 31/100
# 1763/1763 [==============================] - 26s 15ms/step - loss: 0.5080 - sparse_categorical_accuracy: 0.8236 - val_loss: 0.4114 - val_sparse_categorical_accuracy: 0.8566
# Epoch 32/100
# 1763/1763 [==============================] - 26s 15ms/step - loss: 0.5096 - sparse_categorical_accuracy: 0.8230 - val_loss: 0.4025 - val_sparse_categorical_accuracy: 0.8601
# Epoch 33/100
# 1763/1763 [==============================] - 26s 15ms/step - loss: 0.5123 - sparse_categorical_accuracy: 0.8221 - val_loss: 0.4011 - val_sparse_categorical_accuracy: 0.8597
# Epoch 34/100
# 1763/1763 [==============================] - 26s 15ms/step - loss: 0.5081 - sparse_categorical_accuracy: 0.8243 - val_loss: 0.4129 - val_sparse_categorical_accuracy: 0.8584
# Epoch 35/100
# 1763/1763 [==============================] - 27s 16ms/step - loss: 0.5073 - sparse_categorical_accuracy: 0.8241 - val_loss: 0.3948 - val_sparse_categorical_accuracy: 0.8643
# Epoch 36/100
# 1763/1763 [==============================] - 27s 15ms/step - loss: 0.5119 - sparse_categorical_accuracy: 0.8233 - val_loss: 0.4003 - val_sparse_categorical_accuracy: 0.8585
# Epoch 37/100
# 1763/1763 [==============================] - 26s 15ms/step - loss: 0.5050 - sparse_categorical_accuracy: 0.8250 - val_loss: 0.3953 - val_sparse_categorical_accuracy: 0.8632
# Epoch 38/100
# 1763/1763 [==============================] - 27s 15ms/step - loss: 0.5052 - sparse_categorical_accuracy: 0.8256 - val_loss: 0.3907 - val_sparse_categorical_accuracy: 0.8639
# Epoch 39/100
# 1763/1763 [==============================] - 29s 17ms/step - loss: 0.5073 - sparse_categorical_accuracy: 0.8233 - val_loss: 0.4133 - val_sparse_categorical_accuracy: 0.8544
# Epoch 40/100
# 1763/1763 [==============================] - 26s 15ms/step - loss: 0.4976 - sparse_categorical_accuracy: 0.8268 - val_loss: 0.4194 - val_sparse_categorical_accuracy: 0.8543
# Epoch 41/100
# 1763/1763 [==============================] - 26s 15ms/step - loss: 0.5001 - sparse_categorical_accuracy: 0.8257 - val_loss: 0.3952 - val_sparse_categorical_accuracy: 0.8596
# Epoch 42/100
# 1763/1763 [==============================] - 26s 15ms/step - loss: 0.5008 - sparse_categorical_accuracy: 0.8257 - val_loss: 0.4033 - val_sparse_categorical_accuracy: 0.8629
# Epoch 43/100
# 1763/1763 [==============================] - 26s 15ms/step - loss: 0.5003 - sparse_categorical_accuracy: 0.8285 - val_loss: 0.4109 - val_sparse_categorical_accuracy: 0.8575
# Epoch 44/100
# 1763/1763 [==============================] - 29s 16ms/step - loss: 0.4963 - sparse_categorical_accuracy: 0.8277 - val_loss: 0.4023 - val_sparse_categorical_accuracy: 0.8594
# Epoch 45/100
# 1763/1763 [==============================] - 31s 17ms/step - loss: 0.5016 - sparse_categorical_accuracy: 0.8254 - val_loss: 0.3976 - val_sparse_categorical_accuracy: 0.8595

# %%
# list all data in history
print(history.history.keys())
# Out:
# dict_keys(['loss', 'sparse_categorical_accuracy', 'val_loss', 'val_sparse_categorical_accuracy'])

# %%
# summarize history for accuracy
plt.plot(history.history['sparse_categorical_accuracy'])
plt.plot(history.history['val_sparse_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Save Model
model.save("LeNet_EMNIST_trained")
# Out:
# INFO:tensorflow:Assets written to: LeNet_EMNIST_trained/assets

# %% [markdown]
# ### Predict Model - EMNIST

# %%
from tensorflow import keras
model = keras.models.load_model('./LeNet_EMNIST_trained')

# %%
# visualiza labels
classes = np.unique(y_val)
plt.figure(figsize = (40, 20))
ind = 1
for i in classes: 
    for index in range(len(y_val)):
        if (y_val[index] == i ):
            plt.subplot(10, 5, ind)
            plt.imshow(X_val[index].reshape(28, 28), cmap = 'gray')
            plt.title('{}'.format(i))
            ind = ind + 1
            break
        pass
plt.show()

# %%
y_pred = model.predict(X_val)

# %%
print(f"LeNet model trained on EMNIST tested on EMNIST has accuracy of {accuracy_score(y_val, np.argmax(y_pred,axis=1))}")
# Out:
# LeNet model trained on EMNIST tested on EMNIST has accuracy of 0.859468085106383

# %% [markdown]
# ### Predict Model - Merged Chars74K (Cross Validation)

# %%
df = pd.read_pickle('char74.pkl')
images = df['X']
labels = df['y']

# %%
# classes that are indistinguishable 
# C: 12, c:38
# K: 20, k: 46
# O: 24, 0: 50
# S: 28, s: 54
# V: 31, v: 57
# P: 25, p: 51
# W: 32, w: 58
# X: 33, x: 59
# Z: 35, z: 61
# I: 18, i: 44
# J: 19, j: 45
# L: 21, l: 47
# M: 22, m: 48
# U: 30, u: 56
# Y: 34, y: 60
d = {12:38,20:46,24:50,28:54,31:57,25:51,32:58,33:59,35:61,18:44,19:45,21:47,22:48,30:56,34:60}
from numpy import copy
newArray = copy(labels)
for k, v in d.items(): 
    newArray[labels==v] = k

# %%
lower_cases = {39:38,40:39,41:40,42:41,43:42,49:43,52:44,53:45,55:46}
new_labels = copy(newArray)
for k, v in lower_cases.items(): 
    new_labels[newArray==k] = v

# %%
X_train_char74, X_val_char74, y_train_char74, y_val_char74 = train_test_split(images, new_labels, test_size = 0.2)

# %%
# visualiza labels
classes = np.unique(y_val_char74)
plt.figure(figsize = (40, 20))
ind = 1
for i in classes: 
    for index in range(len(y_val_char74)):
        if (y_val_char74[index] == i ):
            plt.subplot(10, 5, ind)
            plt.imshow(X_val_char74[index].reshape(28, 28), cmap = 'gray')
            plt.title('{}'.format(i))
            ind = ind + 1
            break
        pass
plt.show()

# %%
X_train_char74 = np.expand_dims(X_train_char74, 3)

X_val_char74 = np.expand_dims(X_val_char74, 3)

# %%
ypred2 = model.predict(X_val_char74)

# %%
print(f"LeNet model trained on EMNIST tested on merged Char74k has accuracy of {accuracy_score(y_val_char74, np.argmax(ypred2,axis=1))}")
# Out:
# LeNet model trained on EMNIST tested on merged Char74k has accuracy of 0.06558441558441558

# %%
#check first 50 labels
y_val_char74[0:50] == np.argmax(ypred2,axis=1)[0:50]
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False])

# %%
# correct predictions in the first 50 data points
sum(y_val_char74[0:50] == np.argmax(ypred2,axis=1)[0:50])
# Out:
# 1

# %% [markdown]
# ### Predict Model - EMNIST & Merged Chars74K Combined

# %%
# emnist data
print(X_train.shape, X_val.shape, y_train.shape, y_val.shape)
emnist_image = np.concatenate((X_train,X_val), axis=0)
emnist_label = np.concatenate((y_train,y_val), axis=0)
print(emnist_image.shape, emnist_label.shape)
# Out:
# (112800, 28, 28, 1) (18800, 28, 28, 1) (112800,) (18800,)
# (131600, 28, 28, 1) (131600,)

# %%
# char74k data
print(X_train_char74.shape, X_val_char74.shape, y_train_char74.shape, y_val_char74.shape)
char74_image = np.concatenate((X_train_char74,X_val_char74), axis=0)
char74_label = np.concatenate((y_train_char74,y_val_char74), axis=0)
print(char74_image.shape, char74_label.shape)
# Out:
# (6160, 28, 28, 1) (1540, 28, 28, 1) (6160,) (1540,)
# (7700, 28, 28, 1) (7700,)

# %%
# combined data
all_image = np.concatenate((emnist_image,char74_image), axis=0)
all_label = np.concatenate((emnist_label,char74_label), axis=0)
print(all_image.shape, all_label.shape)
# Out:
# (139300, 28, 28, 1) (139300,)

# %%
# split train test on combined data
X_train_all, X_val_all, y_train_all, y_val_all = train_test_split(all_image, all_label, test_size = 0.2)

# %%
ypred3 = model.predict(X_val_all)

# %%
print(f"LeNet model trained on EMNIST tested on EMNIST and merged Char74k combined has accuracy of {accuracy_score(y_val_all, np.argmax(ypred3,axis=1))}")
# Out:
# LeNet model trained on EMNIST tested on EMNIST and merged Char74k combined has accuracy of 0.824048815506102

# %% [markdown]
# ## train on Char74k & EMNIST combined

# %%
print(X_train_all.shape, y_train_all.shape)
# Out:
# (111440, 28, 28, 1) (111440,)

# %%
train_dataset_all = tf.data.Dataset.from_tensor_slices((X_train_all, y_train_all))
test_dataset_all = tf.data.Dataset.from_tensor_slices((X_val_all, y_val_all))

# %%
BATCH_SIZE = 64
SHUFFLE_BUFFER_SIZE = 100

train_dataset_all = train_dataset_all.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
test_dataset_all = test_dataset_all.batch(BATCH_SIZE)

# %%
train_dataset_all
# Out:
# <BatchDataset shapes: ((None, 28, 28, 1), (None,)), types: (tf.float64, tf.int64)>

# %%
hist = model.fit(
    train_dataset_all,
    epochs=100,
    callbacks = [callbacks],
    validation_data=test_dataset_all,
)
# Out:
# Epoch 1/100
# 1742/1742 [==============================] - 45s 25ms/step - loss: 0.6909 - sparse_categorical_accuracy: 0.7809 - val_loss: 0.5412 - val_sparse_categorical_accuracy: 0.8246
# Epoch 2/100
# 1742/1742 [==============================] - 100s 57ms/step - loss: 0.6785 - sparse_categorical_accuracy: 0.7812 - val_loss: 0.5407 - val_sparse_categorical_accuracy: 0.8266
# Epoch 3/100
# 1742/1742 [==============================] - 91s 52ms/step - loss: 0.6717 - sparse_categorical_accuracy: 0.7845 - val_loss: 0.5433 - val_sparse_categorical_accuracy: 0.8224
# Epoch 4/100
# 1742/1742 [==============================] - 83s 47ms/step - loss: 0.6709 - sparse_categorical_accuracy: 0.7837 - val_loss: 0.5618 - val_sparse_categorical_accuracy: 0.8175
# Epoch 5/100
# 1742/1742 [==============================] - 123s 71ms/step - loss: 0.6734 - sparse_categorical_accuracy: 0.7824 - val_loss: 0.5445 - val_sparse_categorical_accuracy: 0.8235
# Epoch 6/100
# 1742/1742 [==============================] - 96s 55ms/step - loss: 0.6660 - sparse_categorical_accuracy: 0.7850 - val_loss: 0.5442 - val_sparse_categorical_accuracy: 0.8231
# Epoch 7/100
# 1742/1742 [==============================] - 98s 56ms/step - loss: 0.6651 - sparse_categorical_accuracy: 0.7849 - val_loss: 0.5444 - val_sparse_categorical_accuracy: 0.8220
# Epoch 8/100
# 1742/1742 [==============================] - 105s 60ms/step - loss: 0.6642 - sparse_categorical_accuracy: 0.7857 - val_loss: 0.5501 - val_sparse_categorical_accuracy: 0.8220
# Epoch 9/100
# 1742/1742 [==============================] - 104s 60ms/step - loss: 0.6641 - sparse_categorical_accuracy: 0.7848 - val_loss: 0.5476 - val_sparse_categorical_accuracy: 0.8231
# Epoch 10/100
# 1742/1742 [==============================] - 97s 56ms/step - loss: 0.6629 - sparse_categorical_accuracy: 0.7855 - val_loss: 0.5647 - val_sparse_categorical_accuracy: 0.8176
# Epoch 11/100
# 1742/1742 [==============================] - 95s 54ms/step - loss: 0.6656 - sparse_categorical_accuracy: 0.7852 - val_loss: 0.5535 - val_sparse_categorical_accuracy: 0.8179
# Epoch 12/100
# 1742/1742 [==============================] - 120s 69ms/step - loss: 0.6656 - sparse_categorical_accuracy: 0.7856 - val_loss: 0.5633 - val_sparse_categorical_accuracy: 0.8167

# %%
# summarize history for accuracy
plt.plot(hist.history['sparse_categorical_accuracy'])
plt.plot(hist.history['val_sparse_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
ypred4 = model.predict(X_val_all)

# %%
print(f"LeNet model trained on EMNIST and merged Char74k combined tested on EMNIST and merged Char74k combined has accuracy of {accuracy_score(y_val_all, np.argmax(ypred4,axis=1))}")
# Out:
# LeNet model trained on EMNIST and merged Char74k combined tested on EMNIST and merged Char74k combined has accuracy of 0.8166905958363245

# %%
# Save Model
model.save("LeNet_EMNIST&Char74k_trained")
# Out:
# INFO:tensorflow:Assets written to: LeNet_EMNIST&Char74k_trained/assets
